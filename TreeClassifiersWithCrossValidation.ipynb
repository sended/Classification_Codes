# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from IPython.display import Image
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# %%
iris = pd.read_csv('Iris.csv')
iris.drop(['Id'], axis = 1, inplace = True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
trainX, testX, trainY, testY = train_test_split(iris.drop(['Species'], axis =1), iris.Species, test_size= 0.25, 
                                                stratify = iris['Species'])

# %%
parameters_test = {'criterion':['gini','entropy'], 'splitter':['best', 'random']}

# %%
classficator = DecisionTreeClassifier()

# %%
grid = GridSearchCV(estimator = classficator, param_grid = parameters_test, scoring='accuracy', n_jobs= -1, cv=4)

# %%
grid.fit(trainX, trainY)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'criterion': ['gini', 'entropy'], 'splitter': ['best', 'random']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
print(pd.DataFrame(grid.cv_results_))
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.001995      0.000000         0.001745        0.000432
# 1       0.001995      0.000000         0.001745        0.000432
# 2       0.002244      0.000433         0.001994        0.000000
# 3       0.001496      0.000498         0.000499        0.000499
#
#   param_criterion param_splitter  \
# 0            gini           best
# 1            gini         random
# 2         entropy           best
# 3         entropy         random
#
#                                            params  split0_test_score  \
# 0       {'criterion': 'gini', 'splitter': 'best'}           0.966667
# 1     {'criterion': 'gini', 'splitter': 'random'}           0.933333
# 2    {'criterion': 'entropy', 'splitter': 'best'}           0.966667
# 3  {'criterion': 'entropy', 'splitter': 'random'}           0.933333
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.964286           1.000000           0.888889         0.955357
# 1           0.928571           0.962963           0.925926         0.937500
# 2           0.964286           1.000000           0.888889         0.955357
# 3           0.928571           1.000000           0.925926         0.946429
#
#    std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0        0.039996                1                 1.0                 1.0
# 1        0.014601                4                 1.0                 1.0
# 2        0.039996                1                 1.0                 1.0
# 3        0.030312                3                 1.0                 1.0
#
#    split2_train_score  split3_train_score  mean_train_score  std_train_score
# 0                 1.0                 1.0               1.0              0.0
# 1                 1.0                 1.0               1.0              0.0
# 2                 1.0                 1.0               1.0              0.0
# 3                 1.0                 1.0               1.0              0.0
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
print(pd.DataFrame(grid.cv_results_)[['params',  'mean_test_score']])
# Out:
#                                            params  mean_test_score
# 0       {'criterion': 'gini', 'splitter': 'best'}         0.955357
# 1     {'criterion': 'gini', 'splitter': 'random'}         0.937500
# 2    {'criterion': 'entropy', 'splitter': 'best'}         0.955357
# 3  {'criterion': 'entropy', 'splitter': 'random'}         0.946429

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'splitter': 'best'}

# %%
del(grid, parameters_test)

# %%
classficator = DecisionTreeClassifier(criterion='gini', splitter='best')

# %%
classficator.fit(trainX, trainY)
predict = classficator.predict(testX)

# %%
print(confusion_matrix(testY, predict))
# Out:
# [[13  0  0]
#  [ 0 13  0]
#  [ 0  0 12]]

# %%
print(classification_report(testY, predict))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        12
#
#       micro avg       1.00      1.00      1.00        38
#       macro avg       1.00      1.00      1.00        38
#    weighted avg       1.00      1.00      1.00        38

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(classficator, out_file=dot_data, filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph.create_png())

# %%
XC = iris.drop(['Species'], axis = 1) #X completo
XP = iris.drop(['SepalLengthCm', 'SepalWidthCm', 'Species'], axis=1) #X Parcial
Y = iris['Species']

# %%
from sklearn.model_selection import cross_val_score

# %%
tree_ = DecisionTreeClassifier(criterion='gini', splitter='best')
score = cross_val_score(tree_, XC, Y, cv=5)
print(score)
# Out:
# [0.96666667 0.96666667 0.9        0.96666667 1.        ]

# %%
print('A acuracia da Iris com todos atributos tem:')
print('Média: %0.2f e Desvio Padrão de +/-: %0.2f' % (np.mean(score), np.std(score)))
# Out:
# A acuracia da Iris com todos atributos tem:
# Média: 0.96 e Desvio Padrão de +/-: 0.03

# %%
tree_ = DecisionTreeClassifier(criterion='gini', splitter='best')
score = cross_val_score(tree_, XP, Y, cv=5)
print(score)
# Out:
# [0.96666667 0.96666667 0.9        0.93333333 1.        ]

# %%
print('A acuracia da Iris só com atributo da Petalas tem:')
print('Média: %0.2f e Desvio Padrão de +/-: %0.2f' % (np.mean(score), np.std(score)))
# Out:
# A acuracia da Iris só com atributo da Petalas tem:
# Média: 0.95 e Desvio Padrão de +/-: 0.03
